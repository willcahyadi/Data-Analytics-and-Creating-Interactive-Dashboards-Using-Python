# %% [markdown]
# ## Basics of python
#
# In this notebook, we are going to learn about some fo the basic operations and datatypes within python, we will also learn about how we can do simple functions and things such as loops.

# %% [markdown]
# ### In the beginning..
# ###  Data Types in python
#
# * Integers
# * Floats
# * Booleans
# * Strings

# %%
1 + 2
# Out:
# 3

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(type(1+2))
print(type(2.5))
print(type(True)) #boolean is only made up of 2 parts - True/False, its like light switch
print(type("Hello world!"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# #### Variables - They are containers
# They can store anything you want!

# %%
name = "john" # the "=" sign over here is an assignment operator
job = "Construction worker"
pets = 2

# %%
print(name)
print(type(pets))
# Out:
# john
# <class 'int'>

# %% [markdown]
# #### List
# Lists are ordered sequences of elements, with that order being specified by the order that the elements are in when the list is created or as elements are added to the list. <br/>
# - Lists are created using the [] syntax.
# - Lists can include mixed data types.
# - List elements are accessed by index.
# - Lists are mutable. You can add, remove, and replace values using functions such as append(), insert(), pop(), remove().

# %%
blanklist = []
print(type(blanklist))
# Out:
# <class 'list'>

# %%
todolist = ["shower", "Breakfast", "Work", "Grocery"]
todolist
# Out:
# ['shower', 'Breakfast', 'Work', 'Grocery']

# %%
#list indexing
todolist[2]
# Out:
# 'Work'

# %%
#after grocery shopping, i do need to get dinner
todolist.append("Dinner")
todolist
# Out:
# ['shower', 'Breakfast', 'Work', 'Grocery', 'Dinner', 'Dinner', 'Dinner']

# %%
todolist.pop()
todolist
# Out:
# ['shower', 'Breakfast', 'Work', 'Grocery', 'Dinner']

# %%
todolist.pop(0)
todolist
# Out:
# ['Breakfast', 'Work', 'Grocery', 'Dinner']

# %%
todolist.remove("Grocery")
todolist
# Out:
# ['Breakfast', 'Work', 'Dinner']

# %%
todolist.insert(2, "Workout")
todolist
# Out:
# ['Breakfast', 'Work', 'Workout', 'Dinner']

# %%
#pet list
pets = ["elephant", "dogs", "cats", "turtle"]
pets
# Out:
# ['elephant', 'dogs', 'cats', 'turtle']

# %%
pets.sort()
pets
# Out:
# ['cats', 'dogs', 'elephant', 'turtle']

# %%
pets.reverse()
pets
# Out:
# ['turtle', 'elephant', 'dogs', 'cats']

# %% [markdown]
# ## Slicing in lists
#
# [start:stop:skip]

# %%
petlist = ["elephant", "dogs", "cats", "turtle", "donkey", "meerkat", "shark"]
#e.g we want the first 3 elements in our petlist
petlist[0:3] # with slicing itself, we actually go from 0 up till but not including the last element
# Out:
# ['elephant', 'dogs', 'cats']

# %%
len(petlist)
# Out:
# 7

# %%
#say i want the last 2 elements
petlist[5:]
# Out:
# ['meerkat', 'shark']

# %%
petlist[-2:]
# Out:
# ['meerkat', 'shark']

# %%
petlist[0::2] #skip every second element
# Out:
# ['elephant', 'cats', 'donkey', 'shark']

# %% [markdown]
# ## Flow control
#
# * if statements
# * while loops
# * for loops
# * functions

# %% [markdown]
# We will control the flow using:
#
# 1. Logical statements to check for conditions (performing operations only `if` a condition is met)
#
# 2. Continuing execution until a condition is met
#
# 3. Iterating through a sequence of numbers using the `range()` function or sequence.

# %% [markdown]
# ### If statements - from english to code!

# %%
# Buy a litre of milk from the store, if there are organic eggs, buy a dozen

#define variable - hard coding
milk = 0
eggs = 0
organic_eggs = False
#make decisions - i.e at the store
milk = milk + 1

if organic_eggs == True: # the '==' over here indicates a conditional operator
    eggs = eggs + 12   #python is a an indentation based language
else:
    print("There are no organic eggs!")
    
# check on our output
print("we have bought", milk, " litre(s) of milk!")
print("we have bought", eggs, " organic eggs!")
# Out:
# There are no organic eggs!
# we have bought 1  litre(s) of milk!
# we have bought 0  organic eggs!

# %%
milk = 0
eggs = 0
organic_eggs = False
milk = milk + 1
if organic_eggs == True: # the '==' over here indicates a conditional operator
    eggs = eggs + 12   #python is a an indentation based language
else:
    print("There are no organic eggs!")
print("we have bought", milk, " litre(s) of milk!")
print("we have bought", eggs, " organic eggs!")

# %% [markdown]
# ## Loops
#
# A loop is used to repeat a block of commands multiple times. There are two ways to write a loop, one is a `for` loop and the other is a `while` loop. Typically, you use a `for` loop when you know how many times you want to loop, and a `while` loop when looping is based on a conditional that will be modified during the loop.
#
# ## While loops
#
# A `while` loop is pretty simple, it's structure looks like:
#
#     while a_condition:
#         # do something
#         ...
#
# and it continues until `a_condition` is false.

# %%
#while loop to do division
number = 54
div = 5

while number > 0:
    number = number - div
    print(number)
# Out:
# 49
# 44
# 39
# 34
# 29
# 24
# 19
# 14
# 9
# 4
# -1

# %% [markdown]
# ## For loops
#
# A `for` loop lets us repeat a set of commands a defined number of times. The syntax for a `for` loop is just:
#
#     for item in sequence:
#         # do something with item
#         ...
#
# But what is a sequence?
#
# There are lots of functions in Python that will actually return a sequence - they are called *iterators*. An iterator essentially provides the next element in the sequence each time we access it.
#
# The iterator that we will use to demonstrate a for loop is the `range()` function. The range function gives us a sequence of numbers from the first number we give it up until the last number we give it.

# %%
numlist = [1,2,3,4,5,6]
numlist.
for i in numlist:
    print(i * 2)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %%
range?

# %%
for i in range(1,7):
    print(i*2)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %% [markdown]
# ## Functions
# Functions enable this thing called code modularity!
# > def function_name():
# >
# >     statements
# >
# >     return something

# %%
#create a square function
def sqr_a_num(num):
    ''' This function takes in a number and square it!
    We square it using the num argument!'''
    return num * 2

# %%
sqr_a_num(2)
# Out:
# 4

# %%
sqr_a_num(sqr_a_num(2))
# Out:
# 16

# %%
sqr_a_num()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-9e2ec3ab7a54> in <module>
# ----> 1 sqr_a_num()
#
# TypeError: sqr_a_num() missing 1 required positional argument: 'num'

# %%
sqr_a_num("a")
# Out:
# 'aa'

# %% [markdown]
# ### End of basic of python recap
