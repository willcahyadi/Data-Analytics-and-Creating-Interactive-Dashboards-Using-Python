# %% [markdown]
# ## Basics of Python

# %%
1+2
# Out:
# 3

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
print("Hello World")
# Out:
# Hello World

# %%
todolist = ["Shower", "Breakfast", "Work", "Grocery"]
todolist
# Out:
# ['Shower', 'Breakfast', 'Work', 'Grocery']

# %%
todolist[3]
# Out:
# 'Grocery'

# %%
todolist.append("Dinner")
todolist
# Out:
# ['Shower', 'Breakfast', 'Work', 'Grocery', 'Dinner', 'Dinner']

# %%
todolist.pop()
# Out:
# 'Dinner'

# %%
todolist
# Out:
# ['Shower', 'Breakfast', 'Work', 'Grocery', 'Dinner']
